# %%
import math
import numpy  as np
import random as random

# %%
# integers array
int_arr = np.random.randint(0, 100, 10)
print(int_arr)
# Out:
# [81 40 11 33 32 21 23 81 13 57]

# %%
# Iterate arrays and find %3 number
for i in int_arr:
     if i % 3 == 0: print(i)
# Out:
# 81
# 33
# 21
# 81
# 57
